# %% [markdown]
# # Computational Economics and Nonlinear Modeling (2)
#
#
# ## : General Introduction
#
# PSE Summer School, 2017
#
# Pablo Winant

# %% [markdown]
# # Julia Packages
# The goal of this notebook is to quickly introduce Julia packages, useful to modelers.

# %% [markdown]
# ## Packages
#
# Huge ecosystem: http://pkg.julialang.org/pulse.html
#
# Based on Git/Github:
#
# - packages are repositories
# - a package = module + files + scripts
#
# Three types of packages:
#
# - shipped (in [JuliaPro](http://juliacomputing.com/products/juliapro.html))
# - registered (see [METADATA.jl](https://github.com/JuliaLang/METADATA.jl)): install with `Pkg.add()`
# - unregistered: install with  `Pkg.clone()
#
# Using a package:
# - `using Dolo`: imports all the exported functions
# - `import Dolo`: needs qualified access (`Dolo.time_iteration`)

# %% [markdown]
# ## A small list of useful packages:
#
# *nonlinear optimization / minimization*
#
# - Roots
# - Optim
# - NLSolve (*)
#
# *interpolation*
#
# - Interpolations (*)
# - BasisMatrices (*)
# - splines.jl (**)
#
# *Statistics*
#
# - DataFrames
# - Distributions
# - GLM
# - MultivariateStats (*)
#
# *Plotting libraries*
#
# - Gadfly
# - PyPlot
# - Plots (*)
# - Plotly / PlotlyJS (*)
#
# *Formal calculation*
#
# - Calculus
# - SymEngine
# - ForwardDiff (*)
#
# *Modeling*
# - Dolang (**)
# - Dolo (**)
# - Dyno (**)
#
# See [ucidatascienceinitiative](http://ucidatascienceinitiative.github.io/IntroToJulia/) for a more data-oriented introduction.

# %% [markdown]
# ## Juno
#
# Atom-based Julia IDE
#
# - atom features:
#
#     - command palette (ctrl+shift+p), multiple cursors, plugins
#
# - juno features:
#
#     - enable workspace (default layout)
#     - julia console (command line integration)
#     - progressbar
#     - debugger

# %% [markdown]
# ### Exercise 1: basic package management
#
# - list all installed packages
# - find directory of installed packages
# - inspect content of package QuantEcon
# - install (or clone) Dolo.jl

# %% [markdown]
# ## Topic: statistics
#
# - Arrays and DataFrames:
#     - past and present: DataFrames
#     - future:???
#         - database oriented: DataTables ( [JuliaData](https://github.com/JuliaData) )
#         - labelled arrays: AxisArrays or NamedArrays (see [JuliaArrays](https://github.com/JuliaArrays?type=)
# - Satistics (see [JuliaStats](https://github.com/JuliaStats) )
#     - Distributions.jl
#     - StatsBase.jl
#     - RDatasets.jl
#
# - Econometrics
#     - TimeSeries.jl
#     - GLM.jl
#     - Multivariate.jl

# %% [markdown]
# ### Exercise 2: a (tiny) bit of statistics
#
# - Create a simple random DataFrame with the following columns (N=100 observations):
#
#     - x and y random, z = 0.5*x + 0.5 y
#     - $x$ and $y$ correlated (use Distributions.jl)
#
# - Compute descriptive statistics
#
# (for those who have a good connection):
#
# - Load the LifeCycleSavings database from RData using RDatasets.jl.
#
#     - use GLM.jl to regress SR on Pop15, Pop75, DPI, DDPI using OLS

# %% [markdown]
# #### Solution

# %%
import DataFrames
N = 100
col1 = rand(N)
col2 = rand(N);
df = DataFrames.DataFrame(x=col1, y=col2);
df[:z] = df[:x] + df[:y];

# %%
# Base.rand does not do multivariate laws.
import Distributions
Sigma = [0.9 0.1; 0.1 0.85]
mu = [0.0, 0.0]
mvn = Distributions.MvNormal(mu, Sigma)
# Out:
# FullNormal(
# dim: 2
# μ: [0.0, 0.0]
# Σ: [0.9 0.1; 0.1 0.85]
# )

# %%
typeof(mvn)
# Out:
# Distributions.MvNormal{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Array{Float64,1}}

# %%
methods(Distributions.rand)
# Out:
# # 165 methods for generic function "rand":
# rand(::Type{ColorTypes.Gray24}) in ColorTypes at /home/pablo/.julia/v0.6/ColorTypes/src/operations.jl:61
# rand(::Type{ColorTypes.Gray24}, sz::Tuple{Vararg{Int64,N}} where N) in ColorTypes at /home/pablo/.julia/v0.6/ColorTypes/src/operations.jl:62
# rand(::Type{ColorTypes.AGray32}) in ColorTypes at /home/pablo/.julia/v0.6/ColorTypes/src/operations.jl:63
# rand(::Type{ColorTypes.AGray32}, sz::Tuple{Vararg{Int64,N}} where N) in ColorTypes at /home/pablo/.julia/v0.6/ColorTypes/src/operations.jl:64
# rand(rd::RandomDevice, ::Type{T}) where T<:Union{Bool, Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base.Random at random.jl:53
# rand(rng::RandomDevice, ::Type{Base.Random.Close1Open2}) in Base.Random at random.jl:66
# rand(rng::RandomDevice, ::Type{Base.Random.CloseOpen}) in Base.Random at random.jl:69
# rand(r::MersenneTwister, ::Type{I}) where I<:Base.Random.FloatInterval in Base.Random at random.jl:138
# rand(r::MersenneTwister, ::Type{T}) where T<:Union{Bool, Int16, Int32, Int8, UInt16, UInt32, UInt8} in Base.Random at random.jl:324
# rand(r::MersenneTwister, ::Type{UInt64}) in Base.Random at random.jl:327
# rand(r::MersenneTwister, ::Type{UInt128}) in Base.Random at random.jl:332
# rand(r::MersenneTwister, ::Type{Int64}) in Base.Random at random.jl:338
# rand(r::MersenneTwister, ::Type{Int128}) in Base.Random at random.jl:339
# rand(rng::MbedTLS.CtrDrbg, size::Integer) in MbedTLS at /home/pablo/.julia/v0.6/MbedTLS/src/ctr_drbg.jl:47
# rand(s::StatsBase.RandIntSampler) in StatsBase at /home/pablo/.julia/v0.6/StatsBase/src/rand.jl:19
# rand(d::Distributions.DiscreteUniform) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/discreteuniform.jl:131
# rand(d::Distributions.Hypergeometric) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/hypergeometric.jl:72
# rand(d::Distributions.Kolmogorov) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/kolmogorov.jl:101
# rand(d::Distributions.EmpiricalUnivariateDistribution) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/empirical.jl:67
# rand(s::Distributions.CategoricalDirectSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/categorical.jl:14
# rand(s::Distributions.AliasTable) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/categorical.jl:44
# rand(s::Distributions.BinomialRmathSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/binomial.jl:7
# rand(s::Distributions.BinomialGeomSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/binomial.jl:56
# rand(s::Distributions.BinomialTPESampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/binomial.jl:141
# rand(s::Distributions.BinomialAliasSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/binomial.jl:247
# rand(s::Distributions.BinomialPolySampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/binomial.jl:276
# rand(s::Distributions.PoissBinAliasSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/poissonbinomial.jl:21
# rand(s::Distributions.PoissonRmathSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/poisson.jl:6
# rand(s::Distributions.PoissonCountSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/poisson.jl:28
# rand(s::Distributions.PoissonADSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/poisson.jl:58
# rand(s::Distributions.ExponentialSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/exponential.jl:5
# rand(s::Distributions.ExponentialLogUSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/exponential.jl:12
# rand(s::Distributions.GammaRmathSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/gamma.jl:6
# rand(s::Distributions.GammaGDSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/gamma.jl:70
# rand(s::Distributions.GammaGSSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/gamma.jl:156
# rand(s::Distributions.GammaMTSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/gamma.jl:193
# rand(s::Distributions.VonMisesSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/vonmises.jl:19
# rand(d::Distributions.UnivariateGMM) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/mixtures/unigmm.jl:28
# rand(s::Distributions.UnivariateGMMSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/mixtures/unigmm.jl:38
# rand() in Base.Random at random.jl:276
# rand(::Type{ForwardDiff.Partials{N,V}}) where {N, V} in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/partials.jl:44
# rand(::Type{ForwardDiff.Dual{T,V,N}}) where {T, V, N} in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/dual.jl:256
# rand(::Type{T}) where T<:FixedPointNumbers.FixedPoint in FixedPointNumbers at /home/pablo/.julia/v0.6/FixedPointNumbers/src/FixedPointNumbers.jl:173
# rand(::Type{T}, sz::Tuple{Vararg{Int64,N}} where N) where T<:FixedPointNumbers.FixedPoint in FixedPointNumbers at /home/pablo/.julia/v0.6/FixedPointNumbers/src/FixedPointNumbers.jl:174
# rand(::Type{T}, sz::Tuple{Vararg{Int64,N}} where N...) where T<:ColorTypes.Colorant in ColorTypes at /home/pablo/.julia/v0.6/ColorTypes/src/operations.jl:59
# rand(T::Type) in Base.Random at random.jl:277
# rand(dims::Tuple{Vararg{Int64,N}} where N) in Base.Random at random.jl:278
# rand(dims::Integer...) in Base.Random at random.jl:279
# rand(T::Type, dims::Tuple{Vararg{Int64,N}} where N) in Base.Random at random.jl:280
# rand(T::Type, d1::Integer, dims::Integer...) in Base.Random at random.jl:281
# rand(partials::ForwardDiff.Partials) in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/partials.jl:43
# rand(r::AbstractArray) in Base.Random at random.jl:284
# rand(r::AbstractArray, dims::Tuple{Vararg{Int64,N}} where N) in Base.Random at random.jl:295
# rand(r::AbstractArray, dims::Integer...) in Base.Random at random.jl:296
# rand(r::Union{MersenneTwister, RandomDevice}, ::Type{Float64}) in Base.Random at random.jl:303
# rand(r::Union{MersenneTwister, RandomDevice}, ::Type{Float16}) in Base.Random at random.jl:310
# rand(r::Union{MersenneTwister, RandomDevice}, ::Type{Float32}) in Base.Random at random.jl:313
# rand(r::AbstractRNG) in Base.Random at random.jl:300
# rand(r::AbstractRNG, ::Type{Complex{T}}) where T<:Real in Base.Random at random.jl:343
# rand(r::AbstractRNG, ::Type{Char}) in Base.Random at random.jl:348
# rand(r::AbstractRNG, t::Dict) in Base.Random at random.jl:354
# rand(t::Dict) in Base.Random at random.jl:361
# rand(r::AbstractRNG, s::Set) in Base.Random at random.jl:362
# rand(s::Set) in Base.Random at random.jl:363
# rand(r::AbstractRNG, dims::Tuple{Vararg{Int64,N}} where N) in Base.Random at random.jl:367
# rand(r::AbstractRNG, dims::Integer...) in Base.Random at random.jl:368
# rand(rng::AbstractRNG, ::Type{SA}) where SA<:StaticArrays.StaticArray in StaticArrays at /home/pablo/.julia/v0.6/StaticArrays/src/arraymath.jl:46
# rand(rng::AbstractRNG, ::Type{ForwardDiff.Partials{N,V}}) where {N, V} in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/partials.jl:46
# rand(rng::AbstractRNG, ::Type{ForwardDiff.Dual{T,V,N}}) where {T, V, N} in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/dual.jl:258
# rand(r::AbstractRNG, T::Type, dims::Tuple{Vararg{Int64,N}} where N) in Base.Random at random.jl:370
# rand(r::AbstractRNG, T::Type, d1::Integer, dims::Integer...) in Base.Random at random.jl:371
# rand(rng::AbstractRNG, g::Base.Random.RangeGeneratorInt{T,UInt64}) where T<:Union{Int64, UInt64} in Base.Random at random.jl:598
# rand(rng::AbstractRNG, g::Base.Random.RangeGeneratorInt{T,U}) where {T<:Integer, U<:Unsigned} in Base.Random at random.jl:614
# rand(rng::AbstractRNG, g::Base.Random.RangeGeneratorBigInt) in Base.Random at random.jl:624
# rand(rng::AbstractRNG, r::UnitRange{#s266} where #s266<:Union{BigInt, Bool, Signed, Unsigned}) in Base.Random at random.jl:653
# rand(rng::AbstractRNG, ::SA) where SA<:StaticArrays.StaticArray in StaticArrays at /home/pablo/.julia/v0.6/StaticArrays/src/arraymath.jl:45
# rand(rng::AbstractRNG, partials::ForwardDiff.Partials) in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/partials.jl:45
# rand(rng::AbstractRNG, r::AbstractArray) in Base.Random at random.jl:658
# rand(rng::AbstractRNG, r::AbstractArray{T,N} where N, dims::Tuple{Vararg{Int64,N}} where N) where T in Base.Random at random.jl:677
# rand(rng::AbstractRNG, r::AbstractArray, dims::Int64...) in Base.Random at random.jl:678
# rand(rng::AbstractRNG, s::StatsBase.RandIntSampler) in StatsBase at /home/pablo/.julia/v0.6/StatsBase/src/rand.jl:13
# rand(d::Distributions.Bernoulli) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/bernoulli.jl:108
# rand(d::Distributions.Binomial) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/binomial.jl:110
# rand(d::Distributions.Geometric) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/geometric.jl:142
# rand(d::Distributions.NegativeBinomial) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/negativebinomial.jl:86
# rand(d::Distributions.Poisson) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/poisson.jl:87
# rand(d::Distributions.Skellam) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/skellam.jl:86
# rand(d::Distributions.Arcsine) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/arcsine.jl:90
# rand(d::Distributions.Beta) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/beta.jl:118
# rand(d::Distributions.BetaPrime) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/betaprime.jl:112
# rand(d::Distributions.Chisq) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/chisq.jl:84
# rand(d::Distributions.Chi) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/chi.jl:97
# rand(d::Distributions.Exponential) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/exponential.jl:88
# rand(d::Distributions.FDist) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/fdist.jl:103
# rand(d::Distributions.Frechet) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/frechet.jl:140
# rand(d::Distributions.Gamma) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/gamma.jl:89
# rand(d::Distributions.Erlang) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/erlang.jl:76
# rand(d::Distributions.GeneralizedPareto) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/generalizedpareto.jl:182
# rand(d::Distributions.GeneralizedExtremeValue) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/generalizedextremevalue.jl:259
# rand(d::Distributions.Gumbel) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/gumbel.jl:95
# rand(d::Distributions.InverseGamma) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/inversegamma.jl:118
# rand(d::Distributions.InverseGaussian) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/inversegaussian.jl:151
# rand(d::Distributions.Laplace) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/laplace.jl:109
# rand(d::Distributions.Levy) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/levy.jl:93
# rand(d::Distributions.Logistic) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/logistic.jl:104
# rand(d::Distributions.NoncentralBeta) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/noncentralbeta.jl:33
# rand(d::Distributions.NoncentralChisq) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/noncentralchisq.jl:73
# rand(d::Distributions.NoncentralF) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/noncentralf.jl:50
# rand(d::Distributions.NoncentralT) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/noncentralt.jl:48
# rand(d::Distributions.Normal) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:81
# rand(cf::Distributions.NormalCanon) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/normalcanon.jl:74
# rand(d::Distributions.LogNormal) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/lognormal.jl:120
# rand(d::Distributions.Pareto) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/pareto.jl:112
# rand(d::Distributions.Rayleigh) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/rayleigh.jl:86
# rand(d::Distributions.SymTriangularDist) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/symtriangular.jl:139
# rand(d::Distributions.TDist) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/tdist.jl:74
# rand(d::Distributions.TriangularDist) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/triangular.jl:146
# rand(d::Distributions.Uniform) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/uniform.jl:106
# rand(d::Distributions.Weibull) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/weibull.jl:136
# rand(d::Distributions.Truncated{Distributions.Normal{T},Distributions.Continuous}) where T<:Real in Distributions at /home/pablo/.julia/v0.6/Distributions/src/truncated/normal.jl:68
# rand(d::Distributions.Truncated) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/truncate.jl:86
# rand(d::Distributions.MixtureModel) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/mixtures/mixturemodel.jl:399
# rand(d::Distributions.Distribution{Distributions.Univariate,S} where S<:Distributions.ValueSupport) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariates.jl:64
# rand(d::Distributions.Distribution{Distributions.Univariate,S} where S<:Distributions.ValueSupport, shp::Tuple{Vararg{Int64,N}} where N) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariates.jl:68
# rand(s::Distributions.GammaIPSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/gamma.jl:222
# rand(s::Distributions.MixtureSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/mixtures/mixturemodel.jl:401
# rand(s::Distributions.Sampleable{Distributions.Univariate,S} where S<:Distributions.ValueSupport, dims::Tuple{Vararg{Int64,N}} where N) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/genericrand.jl:13
# rand(d::Distributions.Distribution{Distributions.Univariate,S} where S<:Distributions.ValueSupport, n::Int64) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariates.jl:67
# rand(s::Distributions.Sampleable{Distributions.Univariate,S} where S<:Distributions.ValueSupport, dims::Int64...) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/genericrand.jl:16
# rand(d::Distributions.Distribution{Distributions.Multivariate,S} where S<:Distributions.ValueSupport) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/multivariates.jl:17
# rand(d::Distributions.Distribution{Distributions.Multivariate,S} where S<:Distributions.ValueSupport, n::Int64) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/multivariates.jl:18
# rand(s::Distributions.Sampleable{Distributions.Multivariate,S} where S<:Distributions.ValueSupport) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/genericrand.jl:41
# rand(s::Distributions.Sampleable{Distributions.Multivariate,S} where S<:Distributions.ValueSupport, n::Int64) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/genericrand.jl:44
# rand(d::Distributions.Wishart) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/matrix/wishart.jl:106
# rand(d::Distributions.InverseWishart) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/matrix/inversewishart.jl:94
# rand(d::Distributions.Distribution{Distributions.Matrixvariate,S} where S<:Distributions.ValueSupport, n::Int64) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/matrixvariates.jl:7
# rand(s::Distributions.Sampleable{Distributions.Matrixvariate,S} where S<:Distributions.ValueSupport, n::Int64) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/genericrand.jl:60
# rand(rng::AbstractRNG, d::Distributions.Bernoulli) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/bernoulli.jl:109
# rand(rng::AbstractRNG, d::Distributions.Geometric) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/discrete/geometric.jl:143
# rand(rng::AbstractRNG, d::Distributions.Arcsine) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/arcsine.jl:91
# rand(rng::AbstractRNG, d::Distributions.Exponential) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/exponential.jl:89
# rand(rng::AbstractRNG, d::Distributions.Frechet) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/frechet.jl:141
# rand(rng::AbstractRNG, d::Distributions.GeneralizedPareto) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/generalizedpareto.jl:185
# rand(rng::AbstractRNG, d::Distributions.GeneralizedExtremeValue) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/generalizedextremevalue.jl:261
# rand(rng::AbstractRNG, d::Distributions.Gumbel) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/gumbel.jl:96
# rand(rng::AbstractRNG, d::Distributions.InverseGaussian) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/inversegaussian.jl:153
# rand(rng::AbstractRNG, d::Distributions.Kolmogorov) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/kolmogorov.jl:103
# rand(rng::AbstractRNG, d::Distributions.Laplace) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/laplace.jl:110
# rand(rng::AbstractRNG, d::Distributions.Levy) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/levy.jl:94
# rand(rng::AbstractRNG, d::Distributions.Logistic) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/logistic.jl:105
# rand(rng::AbstractRNG, d::Distributions.Normal) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:82
# rand(rng::AbstractRNG, cf::Distributions.NormalCanon) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/normalcanon.jl:75
# rand(rng::AbstractRNG, d::Distributions.LogNormal) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/lognormal.jl:121
# rand(rng::AbstractRNG, d::Distributions.Pareto) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/pareto.jl:113
# rand(rng::AbstractRNG, d::Distributions.Rayleigh) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/rayleigh.jl:87
# rand(rng::AbstractRNG, d::Distributions.SymTriangularDist) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/symtriangular.jl:140
# rand(rng::AbstractRNG, d::Distributions.TriangularDist) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/triangular.jl:148
# rand(rng::AbstractRNG, d::Distributions.Uniform) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/uniform.jl:107
# rand(rng::AbstractRNG, d::Distributions.Weibull) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/univariate/continuous/weibull.jl:137
# rand(rng::AbstractRNG, s::Distributions.ExponentialSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/exponential.jl:6
# rand(rng::AbstractRNG, s::Distributions.ExponentialLogUSampler) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/samplers/exponential.jl:13
# rand(rng::AbstractRNG, range::AbstractArray, ::SA) where SA<:StaticArrays.StaticArray in StaticArrays at /home/pablo/.julia/v0.6/StaticArrays/src/arraymath.jl:59
# rand(rng::AbstractRNG, range::AbstractArray, ::Type{SA}) where SA<:StaticArrays.StaticArray in StaticArrays at /home/pablo/.julia/v0.6/StaticArrays/src/arraymath.jl:60
# rand(d::ForwardDiff.Dual) in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/dual.jl:255
# rand(rng::AbstractRNG, d::ForwardDiff.Dual) in ForwardDiff at /home/pablo/.julia/v0.6/ForwardDiff/src/dual.jl:257

# %%
M = Distributions.rand(mvn, N)
# Out:
# 2×100 Array{Float64,2}:
#  1.11152    2.51363   0.544414  0.0840355  …  0.165553  -0.211888   0.767247
#  0.615823  -0.221542  0.416668  0.69762       0.60842    0.543702  -0.343747

# %%
df2 = DataFrames.DataFrame(x=M[1,:], y=M[2,:]);
df2[:z] = df2[:x] + df2[:y];

# %%
# now descriptive statistics

# %%
std(df[:x])
# Out:
# 0.306086098791459

# %%
cor(df) # doesn't work
# Out:
# MethodError: no method matching cor(::DataFrames.DataFrame)
# Closest candidates are:
#   cor(::DataArrays.DataArray{T,1} where T, ::DataArrays.DataArray{T,1} where T) at /home/pablo/.julia/v0.6/DataArrays/src/operators.jl:676
#   cor(::AbstractArray{T,1} where T) at statistics.jl:497
#   cor(::AbstractArray{T,2} where T, ::Int64) at statistics.jl:505
#   ...

# %%
# let's see what cor is defined for
methods(cor)
# Out:
# # 12 methods for generic function "cor":
# cor(dv1::DataArrays.DataArray{T,1} where T, dv2::DataArrays.DataArray{T,1} where T) in DataArrays at /home/pablo/.julia/v0.6/DataArrays/src/operators.jl:676
# cor(x::AbstractArray{T,1} where T) in Base at statistics.jl:497
# cor(X::AbstractArray{T,2} where T, vardim::Int64) in Base at statistics.jl:505
# cor(x::DenseArray{T,2} where T, w::StatsBase.AbstractWeights) in StatsBase at /home/pablo/.julia/v0.6/StatsBase/src/cov.jl:111
# cor(x::DenseArray{T,2} where T, w::StatsBase.AbstractWeights, vardim::Int64) in StatsBase at /home/pablo/.julia/v0.6/StatsBase/src/cov.jl:111
# cor(X::AbstractArray{T,2} where T) in Base at statistics.jl:507
# cor(x::AbstractArray{T,1} where T, y::AbstractArray{T,1} where T) in Base at statistics.jl:514
# cor(x::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T, y::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T, vardim::Int64) in Base at statistics.jl:522
# cor(x::AbstractArray{T,1} where T, Y::AbstractArray{T,2} where T) in Base at statistics.jl:525
# cor(X::AbstractArray{T,2} where T, y::AbstractArray{T,1} where T) in Base at statistics.jl:526
# cor(X::AbstractArray{T,2} where T, Y::AbstractArray{T,2} where T) in Base at statistics.jl:527
# cor(d::Distributions.Distribution{Distributions.Multivariate,S} where S<:Distributions.ValueSupport) in Distributions at /home/pablo/.julia/v0.6/Distributions/src/multivariates.jl:40

# %%
# OK so we need to pass an array: Array(x) converts x to an array
cor(Array(df2))
# Out:
# 3×3 Array{Float64,2}:
#   1.0        -0.0529814  0.735226
#  -0.0529814   1.0        0.637916
#   0.735226    0.637916   1.0

# %% [markdown]
# Economists experiences with R should try RDatasets, GLM

# %%
import RDatasets
LifeCycleSavings = RDatasets.dataset("datasets", "LifeCycleSavings")
# Out:
# 50×6 DataFrames.DataFrame
# │ Row │ Country          │ SR    │ Pop15 │ Pop75 │ DPI     │ DDPI  │
# ├─────┼──────────────────┼───────┼───────┼───────┼─────────┼───────┤
# │ 1   │ "Australia"      │ 11.43 │ 29.35 │ 2.87  │ 2329.68 │ 2.87  │
# │ 2   │ "Austria"        │ 12.07 │ 23.32 │ 4.41  │ 1507.99 │ 3.93  │
# │ 3   │ "Belgium"        │ 13.17 │ 23.8  │ 4.43  │ 2108.47 │ 3.82  │
# │ 4   │ "Bolivia"        │ 5.75  │ 41.89 │ 1.67  │ 189.13  │ 0.22  │
# │ 5   │ "Brazil"         │ 12.88 │ 42.19 │ 0.83  │ 728.47  │ 4.56  │
# │ 6   │ "Canada"         │ 8.79  │ 31.72 │ 2.85  │ 2982.88 │ 2.43  │
# │ 7   │ "Chile"          │ 0.6   │ 39.74 │ 1.34  │ 662.86  │ 2.67  │
# │ 8   │ "China"          │ 11.9  │ 44.75 │ 0.67  │ 289.52  │ 6.51  │
# │ 9   │ "Colombia"       │ 4.98  │ 46.64 │ 1.06  │ 276.65  │ 3.08  │
# │ 10  │ "Costa Rica"     │ 10.78 │ 47.64 │ 1.14  │ 471.24  │ 2.8   │
# │ 11  │ "Denmark"        │ 16.85 │ 24.42 │ 3.93  │ 2496.53 │ 3.99  │
# ⋮
# │ 39  │ "Sweden"         │ 6.86  │ 21.44 │ 4.54  │ 3299.49 │ 3.01  │
# │ 40  │ "Switzerland"    │ 14.13 │ 23.49 │ 3.73  │ 2630.96 │ 2.7   │
# │ 41  │ "Turkey"         │ 5.13  │ 43.42 │ 1.08  │ 389.66  │ 2.96  │
# │ 42  │ "Tunisia"        │ 2.81  │ 46.12 │ 1.21  │ 249.87  │ 1.13  │
# │ 43  │ "United Kingdom" │ 7.81  │ 23.27 │ 4.46  │ 1813.93 │ 2.01  │
# │ 44  │ "United States"  │ 7.56  │ 29.81 │ 3.43  │ 4001.89 │ 2.45  │
# │ 45  │ "Venezuela"      │ 9.22  │ 46.4  │ 0.9   │ 813.39  │ 0.53  │
# │ 46  │ "Zambia"         │ 18.56 │ 45.25 │ 0.56  │ 138.33  │ 5.14  │
# │ 47  │ "Jamaica"        │ 7.72  │ 41.12 │ 1.73  │ 380.47  │ 10.23 │
# │ 48  │ "Uruguay"        │ 9.24  │ 28.13 │ 2.72  │ 766.54  │ 1.88  │
# │ 49  │ "Libya"          │ 8.89  │ 43.69 │ 2.07  │ 123.58  │ 16.71 │
# │ 50  │ "Malaysia"       │ 4.71  │ 47.2  │ 0.66  │ 242.69  │ 5.08  │

# %% [markdown]
# Library GLM uses a syntax close to R's lm for regressions.

# %%
using GLM
fm2 = fit(LinearModel, SR ~ Pop15 + Pop75 + DPI + DDPI, LifeCycleSavings)
# Out:
# UndefVarError: SR not defined

# %%
fm2
# Out:
# UndefVarError: fm2 not defined

# %% [markdown]
# ## Topic: Plotting
#
#
# - PyPlot
#     - (transparent wrapper to Python's Matplotlib)
#     - very mature, publication-grade quality, even better with 2.0
#     - matlab-like interface
# - Gadfly
#     - native Julia
#     - grammar of graphics approach
# - Plotly/PlotlyJS
#     - very complete API
#     - produces interactive Javascript
# - Plots
#     - simple to use higher level api

# %% [markdown]
# ### Exercise 3: plotting
#
# Using PyPlot and/or Gadfly:
#
# - plot $f: x\rightarrow \frac{sin(\epsilon + \frac{a |x|}{\pi})}{\epsilon + \frac{a |x|}{\pi}}$ for different values of a on the same graph (with labels, titles, ...)
# - plot a contour plot for $g: x, y\rightarrow \frac{sin(\frac{\sqrt{x^2+y^2}}{\pi})}{\frac{\sqrt{x^2+y^2}}{\pi}}$
#
# - (optional): use Plotly or Plots
# - (optional 2):  make a 3d graph for $g(x,y)$ using Plotly

# %% [markdown]
# #### Solution

# %%
epsilon = 0.01
f(x, a) = sin(epsilon + a*sqrt(x^2))/(epsilon + a*sqrt(x^2))
g(x) = sin(epsilon + sqrt(x[1]^2+x[2]^2))/(epsilon + sqrt(x[1]^2+x[2]^2))
# Out:
# g (generic function with 1 method)

# %%
xvec = collect(linspace(0,2,1000))
yvec = f.(xvec, 1.0);

# %% [markdown]
# Let's use Gadfly

# %%
using Gadfly
plot(x=xvec, y=yvec, Geom.line)
# Out:
# Plot(...)

# %%
# what if we want to plot many graphs ?
xvec = collect(linspace(0,2,1000))
yvecs = [f.(xvec, a) for a=[1,2,3,4,5]]
layers = [layer(x=xvec, y=yvecs[i], Geom.line) for i=1:length(yvecs)]
plot(layers...)
# Out:
# UndefVarError: layer not defined
#
# Stacktrace:
#  [1] #7 at ./<missing>:0 [inlined]
#  [2] next at ./generator.jl:45 [inlined]
#  [3] collect(::Base.Generator{UnitRange{Int64},##7#8}) at ./array.jl:429

# %%
# but it's easier to construct a dataframe first:
data = vcat(
    DataFrames.DataFrame(x=xvec,y=f.(xvec, 1.0), label="a=1"),
    DataFrames.DataFrame(x=xvec,y=f.(xvec, 2.0), label="a=2"),
    DataFrames.DataFrame(x=xvec,y=f.(xvec, 3.0), label="a=3")
);

# %%
plot(data, x="x", y="y", color=:label, Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# We can do the same with PyPlot which is a wrapper to the <del>easier</del> more matlabesque library Matplotlib.

# %%
import PyPlot
const plt = PyPlot
# Out:
# PyPlot

# %%
yvecs = [f.(xvec, a) for a=[1,2,3,4,5]]

plt.plot(xvec, yvecs[1], label="a=1")
plt.plot(xvec, yvecs[2], label="a=2")
plt.plot(xvec, yvecs[3], label="a=3")
plt.plot(xvec, yvecs[4], label="a=4")
plt.legend()
s = "\$ \sinc(a x) \$ family"
plt.title(s)
plt.tight_layout()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f318fc7e518>)

# %% [markdown]
# 2d plots with PyPlot

# %%
M = 10
n = 100
fine_grid = vcat( [ [x y] for x = linspace(-M,M,n), y = linspace(-M,M,n) ]... );
xm = reshape(fine_grid[:,1], n,n)
ym = reshape(fine_grid[:,2], n,n);

# %%
vals = [g(fine_grid[i,:]) for i=1:size(fine_grid,1)]
V = reshape(vals, size(xm)...)
# Out:
# 100×100 Array{Float64,2}:
#   0.0706528     0.0708013    0.0695315   …   0.0708013    0.0706528
#   0.0708013     0.0694898    0.0667418       0.0694898    0.0708013
#   0.0695315     0.0667418    0.0625257       0.0667418    0.0695315
#   0.0668856     0.0626285    0.0569845       0.0626285    0.0668856
#   0.0629331     0.0572483    0.050245        0.0572483    0.0629331
#   0.0577687     0.0507231    0.0424561   …   0.0507231    0.0577687
#   0.0515081     0.0431942    0.0337837       0.0431942    0.0515081
#   0.0442849     0.0348185    0.0244066       0.0348185    0.0442849
#   0.0362466     0.025764     0.014511        0.025764     0.0362466
#   0.02755       0.016205     0.00428653      0.016205     0.02755
#   0.0183579     0.00631832  -0.00607894  …   0.00631832   0.0183579
#   0.00883453   -0.00372117  -0.0164031      -0.00372117   0.00883453
#  -0.000857742  -0.0137443   -0.0265131      -0.0137443   -0.000857742
#   ⋮                                      ⋱
#   0.00883453   -0.00372117  -0.0164031      -0.00372117   0.00883453
#   0.0183579     0.00631832  -0.00607894      0.00631832   0.0183579
#   0.02755       0.016205     0.00428653  …   0.016205     0.02755
#   0.0362466     0.025764     0.014511        0.025764     0.0362466
#   0.0442849     0.0348185    0.0244066       0.0348185    0.0442849
#   0.0515081     0.0431942    0.0337837       0.0431942    0.0515081
#   0.0577687     0.0507231    0.0424561       0.0507231    0.0577687
#   0.0629331     0.0572483    0.050245    …   0.0572483    0.0629331
#   0.0668856     0.0626285    0.0569845       0.0626285    0.0668856
#   0.0695315     0.0667418    0.0625257       0.0667418    0.0695315
#   0.0708013     0.0694898    0.0667418       0.0694898    0.0708013
#   0.0706528     0.0708013    0.0695315       0.0708013    0.0706528

# %%
plt.contourf(xm,ym,V,100)
plt.colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f317d941438>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7f317d735eb8>

# %% [markdown]
# ## Topic: Maximization/optimization
#
# Two big organizations:
#
# - JuliaOpt: many wrappers, being streamlined towards mathematical programming
# - JuliaNLsolve:
#     - Optim: maximization
#     - NLSolve: nonlinear solution
# - MathJulia:
#     - Roots: simple api for 1d functions
#
# Remark: the need to jit-compile repeated optimization call partly explains the non-intuitive interfaces.

# %% [markdown]
# ### Exercise 3: maximization with Optim.jl
#
# - Use Optim to find the maximum of g, with initial point $x_0=[0.1, 0.1]$
# - Use Optim to find the maximum of g, with initial point $x_0=[1.1, 5.1]$

# %% [markdown]
# #### Solution

# %%
import Optim

# %%
sol = Optim.optimize(g, [1.1,5.1])
# Out:
# Results of Optimization Algorithm
#  * Algorithm: Nelder-Mead
#  * Starting Point: [1.1,5.1]
#  * Minimizer: [1.3506377650979358,4.275081366233788]
#  * Minimum: -2.172336e-01
#  * Iterations: 27
#  * Convergence: true
#    *  √(Σ(yᵢ-ȳ)²)/n < 1.0e-08: true
#    * Reached Maximum Number of Iterations: false
#  * Objective Calls: 50

# %%
sol0 = Optim.optimize(g, [1.1,5.1], Optim.SimulatedAnnealing())
sol = Optim.optimize(g, sol0.minimizer)
# Out:
# Results of Optimization Algorithm
#  * Algorithm: Nelder-Mead
#  * Starting Point: [2.148464164018616,4.041206467620765]
#  * Minimizer: [3.222177197190903,3.1174979328019643]
#  * Minimum: -2.172336e-01
#  * Iterations: 22
#  * Convergence: true
#    *  √(Σ(yᵢ-ȳ)²)/n < 1.0e-08: true
#    * Reached Maximum Number of Iterations: false
#  * Objective Calls: 51

# %% [markdown]
# ### Exercise 4: solving a nonlinear function with Rootls.jl and NLsolve.jl
#
# 1. First, we would like to find the smallest root $x_0$ such that $f(x_0)=0$ using Roots.jl
#   - find the root $x_0$
#   - start from different initial points
#
# 2. Now we look for some values $(x_0,y_0)$ such that $g(x_0, y_0)=0$ and $y_0=x_0^2$
#   - Define the function which computes the residuals
#   - Find a (many solutions) using NLsolve

# %% [markdown]
# #### Solution
#
# Let's solve a 1-dimensional function using Roots.

# %%
import Roots
# Out:
# INFO: Precompiling module Roots.

# %%
Roots.fzero(x->f(x,1.0), 1.0)
# Out:
# 3.1315926535897933

# %%
xvec = linspace(-10, 10, 100)
zeros = [Roots.fzero(x->f(x,1.0),u0) for u0 in xvec];

# %%
plt.plot(xvec, zeros)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f317d8dceb8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f317d643ac8>

# %% [markdown]
# Now let's solve $g$ using a nonlinear solver.

# %%
import NLsolve

# %%
function residual(z)
    epsilon = 0.0001
    res = zeros(2)
    x = z[1]
    y = z[2]
    res[1] = sin(epsilon + sqrt(x^2+y^2))/(epsilon + sqrt(x^2+y^2))
    res[2] = (y - x^2)
    return res
end
# Out:
# residual (generic function with 1 method)

# %%
@time sol = NLsolve.nlsolve(NLsolve.not_in_place(residual), [+0.5, 0.0])
# Out:
# MethodError: objects of type Array{Float64,1} are not callable
# Use square brackets [] for indexing an Array.
#
# Stacktrace:
#  [1] residual(::Array{Float64,1}) at ./In[22]:3
#  [2] (::NLsolve.#f!#19{#residual})(::Array{Float64,1}, ::Array{Float64,1}) at /home/pablo/.julia/v0.6/NLsolve/src/utils.jl:41
#  [3] (::NLsolve.#fg!#3{Symbol,NLsolve.#f!#19{#residual}})(::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,2}) at /home/pablo/.julia/v0.6/NLsolve/src/differentiable_functions.jl:21
#  [4] trust_region_(::NLsolve.DifferentiableMultivariateFunction, ::Array{Float64,1}, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Float64, ::Bool) at /home/pablo/.julia/v0.6/NLsolve/src/trust_region.jl:105
#  [5] #nlsolve#11(::Symbol, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Function, ::Float64, ::Bool, ::NLsolve.#nlsolve, ::NLsolve.DifferentiableMultivariateFunction, ::Array{Float64,1}) at /home/pablo/.julia/v0.6/NLsolve/src/nlsolve_func_defs.jl:24
#  [6] (::NLsolve.#kw##nlsolve)(::Array{Any,1}, ::NLsolve.#nlsolve, ::NLsolve.DifferentiableMultivariateFunction, ::Array{Float64,1}) at ./<missing>:0
#  [7] #nlsolve#13(::Symbol, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Function, ::Float64, ::Bool, ::Bool, ::NLsolve.#nlsolve, ::NLsolve.#f!#19{#residual}, ::Array{Float64,1}) at /home/pablo/.julia/v0.6/NLsolve/src/nlsolve_func_defs.jl:70
#  [8] nlsolve(::Function, ::Array{Float64,1}) at /home/pablo/.julia/v0.6/NLsolve/src/nlsolve_func_defs.jl:65

# %% [markdown]
# ## Topic: Manipulating equations / models
#
#
# - Differentiating equations:
#
#   - calculus.jl
#   - symengine.jl (faster, c++ dependencies)
#
# - Automatic differentiation (see [JuliaDiff](https://github.com/JuliaDiff):
#
#   - forwardiff.jl
#
# - Dynamic/economic equations
#
#   - dolang
#       - equations with timing
#       - metaprogramming
#       - syntactic checks for model files

# %% [markdown]
# ### Calculus.jl
#
# We can also use Calculus.jl to perform symbolic differentiation.

# %%
import Calculus
Calculus.differentiate("sin(epsilon + sqrt(x^2+y^2))/(epsilon + sqrt(x^2+y^2))", [:x,:y])
# Out:
# 2-element Array{Any,1}:
#  :(((((2x) * (0.5 / sqrt(x ^ 2 + y ^ 2))) * cos(epsilon + sqrt(x ^ 2 + y ^ 2))) * (epsilon + sqrt(x ^ 2 + y ^ 2)) - sin(epsilon + sqrt(x ^ 2 + y ^ 2)) * ((2x) * (0.5 / sqrt(x ^ 2 + y ^ 2)))) / (epsilon + sqrt(x ^ 2 + y ^ 2)) ^ 2)
#  :(((((2y) * (0.5 / sqrt(x ^ 2 + y ^ 2))) * cos(epsilon + sqrt(x ^ 2 + y ^ 2))) * (epsilon + sqrt(x ^ 2 + y ^ 2)) - sin(epsilon + sqrt(x ^ 2 + y ^ 2)) * ((2y) * (0.5 / sqrt(x ^ 2 + y ^ 2)))) / (epsilon + sqrt(x ^ 2 + y ^ 2)) ^ 2)

# %%
function residual!(z, res)
    epsilon = 0.0001
    x = z[1]
    y = z[2]
    res[1] = sin(epsilon + sqrt(x^2+y^2))/(epsilon + sqrt(x^2+y^2))
    res[2] = (y - x^2)
    return res
end
# we copy/paste:
function jacobian!(z, res)
    epsilon = 0.0001
#     res = zeros(2,2)
    x = z[1]
    y = z[2]
    res[1,1] = (((((2x) * (0.5 / sqrt(x ^ 2 + y ^ 2))) * cos(epsilon + sqrt(x ^ 2 + y ^ 2))) * (epsilon + sqrt(x ^ 2 + y ^ 2)) - sin(epsilon + sqrt(x ^ 2 + y ^ 2)) * ((2x) * (0.5 / sqrt(x ^ 2 + y ^ 2)))) / (epsilon + sqrt(x ^ 2 + y ^ 2)) ^ 2)
    res[1,2] = (((((2y) * (0.5 / sqrt(x ^ 2 + y ^ 2))) * cos(epsilon + sqrt(x ^ 2 + y ^ 2))) * (epsilon + sqrt(x ^ 2 + y ^ 2)) - sin(epsilon + sqrt(x ^ 2 + y ^ 2)) * ((2y) * (0.5 / sqrt(x ^ 2 + y ^ 2)))) / (epsilon + sqrt(x ^ 2 + y ^ 2)) ^ 2)
    res[2,1] = -2.0*x
    res[2,2] = 1.0
end
# Out:
# jacobian! (generic function with 1 method)

# %%
sol = NLsolve.nlsolve( NLsolve.DifferentiableMultivariateFunction(residual!, jacobian!), [+0.5, 0.0])
# Out:
# Results of Nonlinear Solver Algorithm
#  * Algorithm: Trust-region with dogleg and autoscaling
#  * Starting Point: [0.5, 0.0]
#  * Zero: [1.63739, 2.68103]
#  * Inf-norm of residuals: 0.000000
#  * Iterations: 6
#  * Convergence: true
#    * |x - x'| < 0.0e+00: false
#    * |f(x)| < 1.0e-08: true
#  * Function Calls (f): 7
#  * Jacobian Calls (df/dx): 7

# %% [markdown]
# ### Dolang.jl
#
# Functions can also be created/differentiated with [Dolang.jl](https://github.com/EconForge/Dolang)

# %%
import Dolang
using Dolang
import Base

# %%
expr = parse("sin(epsilon + sqrt(x^2+y^2))/(epsilon + sqrt(x^2+y^2))")
expr2 = parse("y-x^2")

latex_string = string("\$", Dolang.latex(expr), "\$")
Base.HTML(latex_string)
# Out:
# HTML{String}("\$\\frac{\\text{sin}\\left(\\epsilon+\\text{sqrt}\\left(\\left(x\\right)^{2}+\\left(y\\right)^{2}\\right)\\right)}{\\epsilon+\\text{sqrt}\\left(\\left(x\\right)^{2}+\\left(y\\right)^{2}\\right)}\$")

# %%
ff = Dolang.FunctionFactory([expr, expr2] , [:x,:y], [:epsilon]; funname=:gg)
code = Dolang.make_function(ff)
gg, gg! = eval(code)
# Out:
# (gg, gg!)

# %%
gg([0.0,0.1], [0.00001])
# Out:
# 2-element Array{Float64,1}:
#  0.998334
#  0.1

# %%
gg(Der{1},[0.0,0.1], [0.00001])
# Out:
# 2×2 Array{Float64,2}:
#   0.0  -0.0333033
#  -0.0   1.0
